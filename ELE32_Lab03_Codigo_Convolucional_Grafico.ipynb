# %% [markdown]
# <a href="https://colab.research.google.com/github/samarasrs/ELE-32/blob/main/ELE32_Lab03_Codigo_Convolucional_Grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

Pb_3 = [0.498000, 0.201700, 0.011500, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000]
Pb_4 = [0.495900, 0.224400, 0.009500, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000]
Pb_6 = [0.499700, 0.272000, 0.004200, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000]
PROB_P = [0.5, 0.2, 0.1, 0.05, 0.02, 0.001, 0.0005, 0.0002, 0.0001, 0.00005, 0.00002, 0.00001, 0.000005, 0.000002, 0.000001]

x = PROB_P
y1 = Pb_3
y2 = Pb_4
y3 = Pb_6



fig, ax = plt.subplots(figsize = (12,12))

ax.plot(x, y1, '-r', label='m = 3')
ax.plot(x, y2, '--b', label='m = 4')
ax.plot(x, y3, '--g', label='m = 6')



ax.loglog(basex=2,basey=2)



for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(FormatStrFormatter("%.e"))
ax.set_yticks(x)
ax.set_xticks(x)

ax.set_ylim(0.001,0.5)
ax.set_xlim(0.02,0.5)
ax.invert_xaxis()

#ax.legend(['Sem código', 'Código de Hamming', 'Código próprio'])
ax.set_title("Probabilidade de erro Pb",fontsize=25)
ax.set_xlabel("p",fontsize=25)
ax.set_ylabel("$p_b$",fontsize=25)

leg = ax.legend();
ax.grid()
